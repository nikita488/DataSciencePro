# %%
# %pip install nltk numpy torch scikit-learn tensorflow
# Out:
# ...
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached absl_py-2.3.0-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# ...
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# ...

# %%
# Установка punkt_tab

import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\nikita488\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# %run train.py
# Out:
# 120 patterns
# 12 tags: ['funny', 'game_characters', 'game_facts', 'game_history', 'game_list', 'game_soundtracks', 'game_tips', 'gaming_culture', 'gaming_events', 'goodbye', 'greeting', 'thanks']
# ...

# %%
# %run chat.py
# Out:
# Let's chat! (type 'quit' to exit)
# You: hey bro
# ProGamer228: Hello, ready to play?
# You: what can i play?
# ProGamer228: You should try Elden Ring, Fortnite, or The Legend of Zelda: Tears of the Kingdom!
# You: neat tell me something about games
# ProGamer228: I do not understand...
# You: how about some joke
# ProGamer228: Why don't skeletons play video games? They don't have the guts!
# You: very funny i suck at games how can i improve
# ProGamer228: Always check your surroundings and explore for hidden items!
# You: interesting how can i improve my skills more
# ProGamer228: Team communication is key in multiplayer games!
# You: i wanna listen to some game soundtrack
# ProGamer228: Video game music often adapts dynamically to player actions.
# You: i want to attend a gaming event
# ProGamer228: Gamescom in Germany attracts thousands of gaming fans every year.
# You: i wanna know about iconic game character
# ...
